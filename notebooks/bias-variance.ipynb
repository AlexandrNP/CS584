# %%
import numpy as np
import matplotlib.pyplot as plt

# True function that we want to learn
def true_function(x):
    return x*(x-3)*(x-4)

# Visualizing function
demo_x = np.linspace(0, 10, 1000)
demo_y = np.array(list(map(true_function, demo_x)))

plt.plot(demo_x, demo_y)

# %%
# Generating data
data_points_number = 10
x = np.linspace(0, 10, data_points_number)

# Adding Gaussian noise
# Normal distribution
mean = 0
std = 20
noise = np.random.normal(loc=0, scale=std, size=data_points_number)
y = np.array(list(map(true_function, x))) + noise

plt.scatter(x, y)

# %%
from sklearn.linear_model import LinearRegression

# Making x a matrix
X = x.reshape(-1, 1)
demo_X = demo_x.reshape(-1, 1)

# Training a model
linear_model = LinearRegression()
linear_model.fit(X, y)
print(X)


y_hat = linear_model.predict(demo_X)

plt.scatter(x, y)
plt.plot(demo_x, y_hat)
# Out:
# [[ 0.        ]
#  [ 1.11111111]
#  [ 2.22222222]
#  [ 3.33333333]
#  [ 4.44444444]
#  [ 5.55555556]
#  [ 6.66666667]
#  [ 7.77777778]
#  [ 8.88888889]
#  [10.        ]]

# %%
from sklearn.preprocessing import PolynomialFeatures

# Adding higher degree features
X = x.reshape(-1, 1)
poly = PolynomialFeatures(degree=3)
X = poly.fit_transform(X)
demo_X = demo_x.reshape(-1, 1)
demo_X = poly.transform(demo_X)

# Training a model
linear_model = LinearRegression()
linear_model.fit(X, y)
print(X)


y_hat = linear_model.predict(demo_X)

plt.scatter(x, y)
plt.plot(demo_x, y_hat)
# Out:
# [[   1.            0.            0.            0.        ]
#  [   1.            1.11111111    1.2345679     1.37174211]
#  [   1.            2.22222222    4.9382716    10.9739369 ]
#  [   1.            3.33333333   11.11111111   37.03703704]
#  [   1.            4.44444444   19.75308642   87.7914952 ]
#  [   1.            5.55555556   30.86419753  171.46776406]
#  [   1.            6.66666667   44.44444444  296.2962963 ]
#  [   1.            7.77777778   60.49382716  470.50754458]
#  [   1.            8.88888889   79.01234568  702.33196159]
#  [   1.           10.          100.         1000.        ]]

# %%
# Adding higher degree features
X = x.reshape(-1, 1)
poly = PolynomialFeatures(degree=9)
X = poly.fit_transform(X)
demo_X = demo_x.reshape(-1, 1)
demo_X = poly.transform(demo_X)

# Training a model
linear_model = LinearRegression()
linear_model.fit(X, y)
print(X)


y_hat = linear_model.predict(demo_X)

plt.scatter(x, y)
plt.plot(demo_x, y_hat)
# Out:
# [[1.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [1.00000000e+00 1.11111111e+00 1.23456790e+00 1.37174211e+00
#   1.52415790e+00 1.69350878e+00 1.88167642e+00 2.09075158e+00
#   2.32305731e+00 2.58117479e+00 2.86797199e+00 3.18663555e+00]
#  [1.00000000e+00 2.22222222e+00 4.93827160e+00 1.09739369e+01
#   2.43865264e+01 5.41922810e+01 1.20427291e+02 2.67616202e+02
#   5.94702672e+02 1.32156149e+03 2.93680332e+03 6.52622960e+03]
#  [1.00000000e+00 3.33333333e+00 1.11111111e+01 3.70370370e+01
#   1.23456790e+02 4.11522634e+02 1.37174211e+03 4.57247371e+03
#   1.52415790e+04 5.08052634e+04 1.69350878e+05 5.64502927e+05]
#  [1.00000000e+00 4.44444444e+00 1.97530864e+01 8.77914952e+01
#   3.90184423e+02 1.73415299e+03 7.70734663e+03 3.42548739e+04
#   1.52243884e+05 6.76639485e+05 3.00728660e+06 1.33657182e+07]
#  [1.00000000e+00 5.55555556e+00 3.08641975e+01 1.71467764e+02
#   9.52598689e+02 5.29221494e+03 2.94011941e+04 1.63339967e+05
#   9.07444263e+05 5.04135702e+06 2.80075390e+07 1.55597439e+08]
#  [1.00000000e+00 6.66666667e+00 4.44444444e+01 2.96296296e+02
#   1.97530864e+03 1.31687243e+04 8.77914952e+04 5.85276635e+05
#   3.90184423e+06 2.60122949e+07 1.73415299e+08 1.15610199e+09]
#  [1.00000000e+00 7.77777778e+00 6.04938272e+01 4.70507545e+02
#   3.65950312e+03 2.84628021e+04 2.21377350e+05 1.72182383e+06
#   1.33919631e+07 1.04159713e+08 8.10131102e+08 6.30101968e+09]
#  [1.00000000e+00 8.88888889e+00 7.90123457e+01 7.02331962e+02
#   6.24295077e+03 5.54928957e+04 4.93270184e+05 4.38462386e+06
#   3.89744343e+07 3.46439416e+08 3.07946148e+09 2.73729909e+10]
#  [1.00000000e+00 1.00000000e+01 1.00000000e+02 1.00000000e+03
#   1.00000000e+04 1.00000000e+05 1.00000000e+06 1.00000000e+07
#   1.00000000e+08 1.00000000e+09 1.00000000e+10 1.00000000e+11]]
